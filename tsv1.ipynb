# %% [markdown]
# <a href="https://colab.research.google.com/github/Adhira-Deogade/TextSummarization_PointerGenerator/blob/master/tsv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install a Drive FUSE wrapper.
# https://github.com/astrada/google-drive-ocamlfuse
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 131304 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.3-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.3-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.3-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %%
# Generate auth tokens for Colab
from google.colab import auth
auth.authenticate_user()

# %%
# Generate creds for the Drive FUSE library.
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# Create a directory and mount Google Drive using that directory.
# !mkdir -p My Drive
# !google-drive-ocamlfuse My Drive

# %%
# !ls
# Out:
# adc.json  Drive  My  sample_data

# %%
cd Drive/DeepLearning/SmmarizerFiles/finished_files/chunked/
# Out:
# /content/Drive/DeepLearning/SmmarizerFiles/finished_files/chunked

# %%
cd ..
# Out:
# /content/Drive/DeepLearning/SmmarizerFiles/finished_files

# %%
cd ..
# Out:
# /content/Drive/DeepLearning/SmmarizerFiles

# %%
cd ..
# Out:
# /content/Drive/DeepLearning

# %%
cd TScodes/seungwonpark/pointer-generator/
# Out:
# /content/Drive/DeepLearning/TScodes/seungwonpark/pointer-generator

# %%
ls
# Out:
# attention_decoder.py  decode.py              model.py              util.py
# batcher.py            __init__.py            __pycache__/
# beam_search.py        inspect_checkpoint.py  README.md
# data.py               LICENSE.txt            run_summarization.py

# %%
# !pip install pyrouge
# Out:
# ...
#     100% |████████████████████████████████| 61kB 5.5MB/s
# ...
#   Stored in directory: /root/.cache/pip/wheels/75/d3/0c/e5b04e15b6b87c42e980de3931d2686e14d36e045058983599
# Successfully built pyrouge
# ...

# %%
# !python run_summarization.py --mode=train --data_path=/content/Drive/DeepLearning/SmmarizerFiles/finished_files/chunked/train_* --vocab_path=/content/Drive/DeepLearning/SmmarizerFiles/finished_files/vocab --log_root=/content/Drive/DeepLearning/SmmarizerFiles/finished_files/chunked/adhideo/log/directory --exp_name=myexperiment
# Out:
# INFO:tensorflow:Starting seq2seq_attention in train mode...
# max_size of vocab was specified as 5000; we now have 5000 words. Stopping reading.
# Finished constructing vocabulary of 5000 total words. Last word added: lethal
# creating model...
# INFO:tensorflow:Building graph...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Writing word embedding metadata file to /content/Drive/DeepLearning/SmmarizerFiles/finished_files/chunked/adhideo/log/directory/myexperiment/train/vocab_metadata.tsv...
# WARNING:tensorflow:From /content/Drive/DeepLearning/TScodes/seungwonpark/pointer-generator/model.py:95: LSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# ...
